# %%
import sympy as sp

# %%
x=sp.Symbol('x')

# %%
x
# Out:
# x

# %%
fx=x**2020 + 3*x*x*x -1

# %%
fx
# Out:
# x**2020 + 3*x**3 - 1

# %%
sp.diff(fx, x)
# Out:
# 2020*x**2019 + 9*x**2

# %%
gx = x / (x+1)

# %%
gx
# Out:
# x/(x + 1)

# %%
sp.diff(gx, x)
# Out:
# -x/(x + 1)**2 + 1/(x + 1)

# %%
sp.simplify(sp.diff(gx, x))
# Out:
# (x + 1)**(-2)

# %%
fx = sp.exp(x) / x

# %%
fx
# Out:
# exp(x)/x

# %%
sp.diff(fx, x)
# Out:
# exp(x)/x - exp(x)/x**2

# %%
sp.simplify(sp.diff(fx, x))
# Out:
# (x - 1)*exp(x)/x**2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x
# Out:
# x

# %%
fx=3*sp.log(x,2) - x*sp.log(x)

# %%
fx
# Out:
# -x*log(x) + 3*log(x)/log(2)

# %%
sp.diff(fx, x)
# Out:
# -log(x) - 1 + 3/(x*log(2))

# %%
sp.simplify(sp.diff(fx, x))
# Out:
# -log(x) - 1 + 3/(x*log(2))

# %%
# 합성함수

# %%
(x**2+2)**3
# Out:
# (x**2 + 2)**3

# %%
hx=(x**2+2)**3

# %%
sp.diff(hx,x)
# Out:
# 6*x*(x**2 + 2)**2

# %%
hx=1 / (x**4 +1)**2

# %%
hx
# Out:
# (x**4 + 1)**(-2)

# %%
sp.diff(1)
# Out:
# 0

# %%
sp.diff(x**4+1)
# Out:
# 4*x**3

# %%
sp.diff((x**4+1)**2)
# Out:
# 8*x**3*(x**4 + 1)

# %%
sp.diff(hx,x)
# Out:
# -8*x**3/(x**4 + 1)**3

# %%
# 시그모이드 함수

# %%
import sympy as sp
# 기호 변수 정의
x = sp.symbols('x')
# Sigmoid 함수 정의
sigmoid = 1 / (1 + sp.exp(-x))

# %%
sigmoid
# Out:
# 1/(1 + exp(-x))

# %%
sp.diff(sigmoid, x)
# Out:
# exp(-x)/(1 + exp(-x))**2
